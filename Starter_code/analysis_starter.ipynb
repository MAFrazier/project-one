# %%
# Dependencies
import json
import requests
import pandas as pd

# %%
# URL for GET requests to retrieve tobacco data
url = ("https://data.cdc.gov/resource/wsas-xwh5.json?$query=SELECT%0A%20%20%60year%60%2C%0A%20%20%60locationabbr%60%2C%0A%20%20%60locationdesc%60%2C%0A%20%20%60topicdesc%60%2C%0A%20%20%60measuredesc%60%2C%0A%20%20%60response%60%2C%0A%20%20%60sample_size%60%2C%0A%20%20%60gender%60%2C%0A%20%20%60race%60%2C%0A%20%20%60age%60%2C%0A%20%20%60education%60%0AWHERE%0A%20%20caseless_one_of(%60year%60%2C%20%222017%22)%0A%20%20AND%20(caseless_ne(%60topicdesc%60%2C%20%22Cessation%20(Adults)%22)%0A%20%20%20%20%20%20%20%20%20AND%20(caseless_not_one_of(%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%60measuredesc%60%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22Percent%20of%20Former%20Smokers%20Among%20Ever%20Smokers%22%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20)%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20AND%20caseless_not_one_of(%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%60response%60%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22Not%20Current%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22Never%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22Former%22%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20)))%0AORDER%20BY%20%60year%60%20DESC%20NULL%20FIRST%2C%20%60locationdesc%60%20ASC%20NULL%20LAST")
response = requests.get(url).json()

# Print the response object to the console
print(response)
# Out:
# [{'year': '2017', 'locationabbr': 'AL', 'locationdesc': 'Alabama', 'topicdesc': 'Smokeless Tobacco Use (Adults)', 'measuredesc': 'Frequency of Use', 'response': 'Every Day', 'sample_size': '331', 'gender': 'Overall', 'race': 'All Races', 'age': 'All Ages', 'education': 'All Grades'}, {'year': '2017', 'locationabbr': 'AL', 'locationdesc': 'Alabama', 'topicdesc': 'Cigarette Use (Adults)', 'measuredesc': 'Smoking Frequency', 'response': 'Some Days', 'sample_size': '611', 'gender': 'Female', 'race': 'All Races', 'age': 'All Ages', 'education': 'All Grades'}, {'year': '2017', 'locationabbr': 'AL', 'locationdesc': 'Alabama', 'topicdesc': 'E-Cigarette Use (Adults)', 'measuredesc': 'Frequency of Use', 'response': 'Some Days', 'sample_size': '116', 'gender': 'Female', 'race': 'All Races', 'age': 'All Ages', 'education': 'All Grades'}, {'year': '2017', 'locationabbr': 'AL', 'locationdesc': 'Alabama', 'topicdesc': 'E-Cigarette Use (Adults)', 'measuredesc': 'Frequency of Use', 'response': 'Every
# ...

# %%
print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# [
#     {
#         "age": "All Ages",
#         "education": "All Grades",
#         "gender": "Overall",
#         "locationabbr": "AL",
#         "locationdesc": "Alabama",
#         "measuredesc": "Frequency of Use",
#         "race": "All Races",
#         "response": "Every Day",
#         "sample_size": "331",
#         "topicdesc": "Smokeless Tobacco Use (Adults)",
#         "year": "2017"
#     },
#     {
#         "age": "All Ages",
#         "education": "All Grades",
#         "gender": "Female",
#         "locationabbr": "AL",
#         "locationdesc": "Alabama",
#         "measuredesc": "Smoking Frequency",
#         "race": "All Races",
#         "response": "Some Days",
#         "sample_size": "611",
#         "topicdesc": "Cigarette Use (Adults)",
#         "year": "2017"
#     },
#     {
#         "age": "All Ages",
#         "education": "All Grades",
#         "gender": "Female",
#         "locationabbr": "AL",
#         "locationdesc": "Alabama",
# ...

# %%
df = pd.DataFrame({ "age": "All Ages",
        "education": "All Grades",
        "gender": "Overall",
        "locationabbr": "AL",
        "locationdesc": "Alabama",
        "measuredesc": "Frequency of Use",
        "race": "All Races",
        "response": "Every Day",
        "sample_size": "331",
        "topicdesc": "Smokeless Tobacco Use (Adults)",
        "year": "2017"})
